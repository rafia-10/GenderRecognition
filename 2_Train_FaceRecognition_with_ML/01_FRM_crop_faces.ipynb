# %%
import numpy as np
import cv2
from glob import glob
import matplotlib.pyplot as plt

# %%
fpath = glob('./data/female/*.jpg')
mpath = glob('./data/male/*.jpg')

# %%
for i in range(len(fpath)):
    try:
        #step1- Read Image and convert to RGB
        img = cv2.imread(fpath[i])
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # step2 - Apply Haar cascade classifier
        haar = cv2.CascadeClassifier('./model/haarcascade_frontalface_default.xml')
        grey = cv2.cvtColor(img_rgb,cv2.COLOR_RGB2GRAY)
        faces = haar.detectMultiScale(grey,1.5,5)
        for x,y,w,h in faces:
            # step 3 crop faces
            roi=img[y:y+h, x:x+w]
            # step -4 save image
            cv2.imwrite(f'./crop_data/female/female_{i}.jpg', roi)
    except:
        print('unable to process image')

# %%
### Process all male images

# %%
for i in range(len(mpath)):
    try:
        #step1- Read Image and convert to RGB
        img = cv2.imread(mpath[i])
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # step2 - Apply Haar cascade classifier
        haar = cv2.CascadeClassifier('./model/haarcascade_frontalface_default.xml')
        grey = cv2.cvtColor(img_rgb,cv2.COLOR_RGB2GRAY)
        faces = haar.detectMultiScale(grey,1.5,5)
        for x,y,w,h in faces:
            # step 3 crop faces
            roi=img[y:y+h, x:x+w]
            # step -4 save image
            cv2.imwrite(f'./crop_data/male/male_{i}.jpg', roi)
            
    except:
        print('unable to process image')

# %%
plt.imshow(img_rgb)
plt.axis('off')
plt.show()
